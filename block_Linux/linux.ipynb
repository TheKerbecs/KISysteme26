# %% [markdown]
# <a href="https://colab.research.google.com/github/keuperj/KISysteme26/blob/main/block_Linux/linux.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/keuperj/KISysteme26.git
# Out:
# Cloning into 'KISysteme26'...
# remote: Enumerating objects: 120, done.
# remote: Counting objects: 100% (120/120), done.
# remote: Compressing objects: 100% (115/115), done.
# remote: Total 120 (delta 45), reused 48 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (120/120), 405.19 KiB | 6.75 MiB/s, done.
# Resolving deltas: 100% (45/45), done.
