# %% [markdown]
# # Hive
# We use the *pyHive* lib: https://github.com/dropbox/PyHive
#
# ## Resources
# * [HQL cheat sheet](https://intellipaat.com/mediaFiles/2019/02/Hive-Cheat-Sheet.pdf)
# * [Hive reference](https://cwiki.apache.org/confluence/display/Hive/LanguageManual)
#
# ## Install
# Install *pyHive* from *GitHub*

# %%
# !python3 -m pip install git+https://github.com/dropbox/PyHive.git
# Out:
# Collecting git+https://github.com/dropbox/PyHive.git
#   Cloning https://github.com/dropbox/PyHive.git to /tmp/pip-req-build-gjoz2yz2
#   Running command git clone --filter=blob:none --quiet https://github.com/dropbox/PyHive.git /tmp/pip-req-build-gjoz2yz2
#   Resolved https://github.com/dropbox/PyHive.git to commit ac09074a652fd50e10b57a7f0bbc4f6410961301
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from PyHive==0.7.0.dev0) (1.0.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from PyHive==0.7.0.dev0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->PyHive==0.7.0.dev0) (1.17.0)
# Building wheels for collected packages: PyHive
#   Building wheel for PyHive (setup.py) ... done
#   Created wheel for PyHive: filename=PyHive-0.7.0.dev0-py3-none-any.whl size=54003 sha256=09ccb0e0683bed1f6ef5f1d70b071bf120056622bef8ec665d7a5bceee1c8b77
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9uxb1et6/wheels/ee/f7/90/8587a69c7b2cc86360ff74ecfbfd379fce6188297bafbda821
# Successfully built PyHive
# Installing collected packages: PyHive
# Successfully installed PyHive-0.7.0.dev0

# %%
# !pip install thrift thrift_sasl
# Out:
# Collecting thrift
#   Downloading thrift-0.22.0.tar.gz (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting thrift_sasl
#   Downloading thrift_sasl-0.4.3-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting pure-sasl>=0.6.2 (from thrift_sasl)
#   Downloading pure-sasl-0.6.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from thrift_sasl) (1.17.0)
# Downloading thrift_sasl-0.4.3-py2.py3-none-any.whl (8.3 kB)
# Building wheels for collected packages: thrift, pure-sasl
#   Building wheel for thrift (setup.py) ... done
#   Created wheel for thrift: filename=thrift-0.22.0-cp312-cp312-linux_x86_64.whl size=413530 sha256=94bf122cc63c4b5fdd3c40cd3c8e422ff33f5e86fab8d8538f2a09bf99b897d2
#   Stored in directory: /root/.cache/pip/wheels/03/30/a2/6e53de46f9d8f098a6b7c4a57dbdcafa5f11e87274e139f50b
#   Building wheel for pure-sasl (setup.py) ... done
#   Created wheel for pure-sasl: filename=pure_sasl-0.6.2-py3-none-any.whl size=11423 sha256=eec5b284326e28ae06231c94888853710e261ea43858f91a367e9638d78678b5
#   Stored in directory: /root/.cache/pip/wheels/5d/bf/32/7369b8b034de66e1c91d3ac3dafbff77ae3c97b9c5c97ea1b2
# Successfully built thrift pure-sasl
# Installing collected packages: thrift, pure-sasl, thrift_sasl
# Successfully installed pure-sasl-0.6.2 thrift-0.22.0 thrift_sasl-0.4.3

# %%
#import libs
from pyhive import hive
from TCLIService.ttypes import TOperationState

# %%
# try to connect
server="ec2-108-130-12-157.eu-west-1.compute.amazonaws.com"
cursor = hive.connect(server).cursor()

# %%
#show our databases
cursor.execute('show databases')

# %%
#get data from execution
cursor.fetchall()
# Out:
# [('default',)]

# %%
#use default db
cursor.execute('use default')

# %%
#show tables in db
cursor.execute('show tables')

# %%
cursor.fetchall()
# Out:
# [('hue__tmp_employees',), ('hue__tmp_salaries',)]

# %%
# get table layout
cursor.execute('describe hue__tmp_employees')
cursor.fetchall()
# Out:
# [('field_1', 'bigint', ''),
#  ('field_2', 'string', ''),
#  ('field_3', 'string', ''),
#  ('field_4', 'string', ''),
#  ('field_5', 'string', ''),
#  ('field_6', 'string', '')]

# %%
#select data
cursor.execute('select * from hue__tmp_employees')

# %%
#get daata from selction
employee = cursor.fetchall()

# %%
#have a look
employee[:10]
# Out:
# [(10001, "'1953-09-02'", "'Georgi'", "'Facello'", "'M'", "'1986-06-26'"),
#  (10002, "'1964-06-02'", "'Bezalel'", "'Simmel'", "'F'", "'1985-11-21'"),
#  (10003, "'1959-12-03'", "'Parto'", "'Bamford'", "'M'", "'1986-08-28'"),
#  (10004, "'1954-05-01'", "'Chirstian'", "'Koblick'", "'M'", "'1986-12-01'"),
#  (10005, "'1955-01-21'", "'Kyoichi'", "'Maliniak'", "'M'", "'1989-09-12'"),
#  (10006, "'1953-04-20'", "'Anneke'", "'Preusig'", "'F'", "'1989-06-02'"),
#  (10007, "'1957-05-23'", "'Tzvetan'", "'Zielinski'", "'F'", "'1989-02-10'"),
#  (10008, "'1958-02-19'", "'Saniya'", "'Kalloufi'", "'M'", "'1994-09-15'"),
#  (10009, "'1952-04-19'", "'Sumant'", "'Peac'", "'F'", "'1985-02-18'"),
#  (10010, "'1963-06-01'", "'Duangkaew'", "'Piveteau'", "'F'", "'1989-08-24'")]

# %%
# get salary table layout
cursor.execute('describe hue__tmp_salaries')
cursor.fetchall()
# Out:
# [('field_1', 'bigint', ''),
#  ('field_2', 'bigint', ''),
#  ('field_3', 'string', ''),
#  ('field_4', 'string', '')]

# %%
#select data
cursor.execute('select * from hue__tmp_salaries')

# %%
#get daata from selction
salary = cursor.fetchall()

# %%
salary[:10]
# Out:
# [(10001, 60117, "'1986-06-26'", "'1987-06-26'"),
#  (10001, 62102, "'1987-06-26'", "'1988-06-25'"),
#  (10001, 66074, "'1988-06-25'", "'1989-06-25'"),
#  (10001, 66596, "'1989-06-25'", "'1990-06-25'"),
#  (10001, 66961, "'1990-06-25'", "'1991-06-25'"),
#  (10001, 71046, "'1991-06-25'", "'1992-06-24'"),
#  (10001, 74333, "'1992-06-24'", "'1993-06-24'"),
#  (10001, 75286, "'1993-06-24'", "'1994-06-24'"),
#  (10001, 75994, "'1994-06-24'", "'1995-06-24'"),
#  (10001, 76884, "'1995-06-24'", "'1996-06-23'")]

# %% [markdown]
# ## Ex 1
# Get employees sorted by ``family_name``. Return first 10 entries.

# %%
cursor.execute('SELECT * FROM hue__tmp_employees ORDER BY field_4 LIMIT 10')

# %%
cursor.fetchall()
# Out:
# [(11761, "'1964-07-17'", "'Bartek'", "'Aamodt'", "'M'", "'1991-06-12'"),
#  (493102, "'1962-10-03'", "'Srinidhi'", "'Aamodt'", "'F'", "'1992-11-13'"),
#  (19898, "'1957-03-09'", "'Vidar'", "'Aamodt'", "'M'", "'1988-08-06'"),
#  (12791, "'1960-06-16'", "'Mokhtar'", "'Aamodt'", "'M'", "'1994-08-14'"),
#  (12516, "'1958-06-25'", "'Sreenivas'", "'Aamodt'", "'F'", "'1990-03-06'"),
#  (16572, "'1956-11-26'", "'Matt'", "'Aamodt'", "'M'", "'1987-06-16'"),
#  (18182, "'1963-02-23'", "'Dekang'", "'Aamodt'", "'F'", "'1988-05-25'"),
#  (493601, "'1958-10-17'", "'Sreekrishna'", "'Aamodt'", "'M'", "'1985-03-17'"),
#  (15427, "'1959-03-06'", "'Aluzio'", "'Aamodt'", "'M'", "'1985-03-03'"),
#  (17400, "'1962-03-22'", "'Basim'", "'Aamodt'", "'F'", "'1991-09-15'")]

# %% [markdown]
# ## Ex 2
# Get ``family_name`` and ``salary`` of employees sorted by salary. Return first 100 entries. Hint: you need to join both tables...

# %%
cursor.execute("SELECT e.field_4, s.field_2 FROM hue__tmp_employees e JOIN hue__tmp_salaries s ON e.field_1 = s.field_1 ORDER BY s.field_2 LIMIT 100")
data=cursor.fetchall()

# %%
display(data)
# Out:
# [("'Unno'", 38735),
#  ("'Narwekar'", 38812),
#  ("'Langford'", 38836),
#  ("'Biran'", 38850),
#  ("'Syang'", 38851),
#  ("'Unno'", 38859),
#  ("'Reinhard'", 38874),
#  ("'Copas'", 38888),
#  ("'Perri'", 38928),
#  ("'Rosis'", 39006),
#  ("'Narwekar'", 39012),
#  ("'Cooke'", 39020),
#  ("'Kushnir'", 39035),
#  ("'Limongiello'", 39036),
#  ("'Hoogerwoord'", 39046),
#  ("'Schauser'", 39050),
#  ("'Onuegbe'", 39054),
#  ("'Langford'", 39060),
#  ("'Zhang'", 39062),
#  ("'Kushnir'", 39063),
#  ("'Backhouse'", 39066),
#  ("'Narwekar'", 39069),
#  ("'Bail'", 39072),
#  ("'Butner'", 39089),
#  ("'Navazio'", 39098),
#  ("'Fritzsche'", 39105),
#  ("'Cincotta'", 39117),
#  ("'Seiwald'", 39119),
#  ("'Cesareni'", 39120),
#  ("'Erdmenger'", 39124),
#  ("'Gomatam'", 39127),
#  ("'Tomescu'", 39128),
#  ("'Mamelak'", 39128),
#  ("'Reeken'", 39129),
#  ("'Ozeki'", 39142),
#  ("'Masamoto'", 39143),
#  ("'Brizzi'", 39143),
#  ("'Peac'", 39146),
#  ("'McFarlin'", 39146),
#  ("'Uchoa'", 39161),
#  ("'Harbusch'", 39166),
#  ("'Griswold'", 39166),
#  ("'Ambroszkiewicz'", 39171),
#  ("'Zuberek'", 39177),
#  ("'Dulin'", 39182),
#  ("'Gruenwald'", 39183),
#  ("'Marrakchi'", 39186),
#  ("'Broder'", 39187),
#  ("'Ernst'", 39192),
#  ("'Yoshizawa'", 39198),
#  ("'Anick'", 39201),
#  ("'Spell'", 39205),
#  ("'Garigliano'", 39212),
#  ("'Jullig'", 39216),
#  ("'Hegner'", 39217),
#  ("'Copas'", 39221),
#  ("'Zirintsis'", 39222),
#  ("'Kusakabe'", 39225),
#  ("'Pelc'", 39229),
#  ("'Biran'", 39230),
#  ("'Farrel'", 39236),
#  ("'Sankaranarayanan'", 39236),
#  ("'Beutelspacher'", 39239),
#  ("'Schaft'", 39246),
#  ("'Basawa'", 39250),
#  ("'Pavlopoulou'", 39251),
#  ("'Chimia'", 39253),
#  ("'Luef'", 39254),
#  ("'Schieder'", 39256),
#  ("'Erez'", 39257),
#  ("'Cincotta'", 39259),
#  ("'Birsak'", 39260),
#  ("'Lindqvist'", 39264),
#  ("'Benzmuller'", 39265),
#  ("'Erni'", 39266),
#  ("'Unni'", 39267),
#  ("'Syang'", 39270),
#  ("'Henders'", 39271),
#  ("'Narwekar'", 39273),
#  ("'Ashish'", 39274),
#  ("'Reinhard'", 39275),
#  ("'Soicher'", 39279),
#  ("'Peot'", 39280),
#  ("'Lamparter'", 39281),
#  ("'Skrikant'", 39282),
#  ("'Mullainathan'", 39283),
#  ("'Turnbull'", 39285),
#  ("'Ramalingam'", 39289),
#  ("'Roison'", 39291),
#  ("'Skrikant'", 39294),
#  ("'Verhoeff'", 39295),
#  ("'Swiss'", 39300),
#  ("'Douceur'", 39301),
#  ("'Pehl'", 39301),
#  ("'Langford'", 39303),
#  ("'Seiwald'", 39307),
#  ("'Chachaty'", 39313),
#  ("'Brookner'", 39314),
#  ("'Dechter'", 39319),
#  ("'Stifter'", 39321)]

# %% [markdown]
# ## Ex 3
# Get the average salary by gender. Hint: use Group by

# %%
cursor.execute("SELECT e.field_5, AVG(s.field_2) FROM hue__tmp_employees e JOIN hue__tmp_salaries s ON e.field_1 = s.field_1 GROUP BY e.field_5")

# %%
display(cursor.fetchall())
# Out:
# [("'F'", 63760.08469915328), ("'M'", 63758.86649934126)]
